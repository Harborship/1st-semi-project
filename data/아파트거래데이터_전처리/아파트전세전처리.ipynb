# %%
import pandas as pd
from difflib import SequenceMatcher
from selenium.webdriver import Chrome
from selenium.webdriver.common.by import By
import pandas as pd
from tqdm import tqdm

# %%
# 데이터 불러오기
apt_df = pd.read_csv('./전세_아파트_리스트.csv', encoding='cp949')
apart_df = pd.read_csv('./전세_전처리_데이터.csv')
apart_df=apart_df[~apart_df['단지명'].str.contains("임대")]
apart_df.reset_index(drop=True, inplace=True)

# %%
apart_df
# Out:
#                          주소             단지명 전월세구분  전용면적(㎡)    계약년월  계약일  \
# 0       서울특별시 강남구 개포동 655-2  개포2차현대아파트(220)    전세    77.75  201501   13
# 1       서울특별시 강남구 개포동 655-2  개포2차현대아파트(220)    전세    77.75  201503    2
# 2       서울특별시 강남구 개포동 655-2  개포2차현대아파트(220)    전세    77.75  201505   23
# 3       서울특별시 강남구 개포동 655-2  개포2차현대아파트(220)    전세    77.75  201506    8
# 4       서울특별시 강남구 개포동 655-2  개포2차현대아파트(220)    전세    77.75  201507   22
# ...                     ...             ...   ...      ...     ...  ...
# 818132    서울특별시 중랑구 중화동 450  한신아파트(103~109)    전세    50.37  202204    2
# 818133    서울특별시 중랑구 중화동 450  한신아파트(103~109)    전세    50.37  202204    2
# 818134    서울특별시 중랑구 중화동 450  한신아파트(103~109)    전세    59.76  202204   16
# 818135    서울특별시 중랑구 중화동 450  한신아파트(103~109)    전세    84.69  202204   27
# 818136    서울특별시 중랑구 중화동 450  한신아파트(103~109)    전세    59.76  202204   30
#
#        보증금(만원)   층    건축년도      도로명                동_단지            시군구     번지
# 0       40,000   5  1988.0  언주로 103  개포동 개포2차현대아파트(220)  서울특별시 강남구 개포동  655-2
# 1       50,000   2  1988.0  언주로 103  개포동 개포2차현대아파트(220)  서울특별시 강남구 개포동  655-2
# 2       50,000   6  1988.0  언주로 103  개포동 개포2차현대아파트(220)  서울특별시 강남구 개포동  655-2
# 3       49,000   3  1988.0  언주로 103  개포동 개포2차현대아파트(220)  서울특별시 강남구 개포동  655-2
# 4       50,000   9  1988.0  언주로 103  개포동 개포2차현대아파트(220)  서울특별시 강남구 개포동  655-2
# ...        ...  ..     ...      ...                 ...            ...    ...
# 818132  37,000  21  1997.0  동일로 752  중화동 한신아파트(103~109)  서울특별시 중랑구 중화동    450
# 818133  37,000  21  1997.0  동일로 752  중화동 한신아파트(103~109)  서울특별시 중랑구 중화동    450
# 818134  46,000   4  1997.0  동일로 752  중화동 한신아파트(103~109)  서울특별시 중랑구 중화동    450
# 818135  51,000   7  1997.0  동일로 752  중화동 한신아파트(103~109)  서울특별시 중랑구 중화동    450
# 818136  33,600  23  1997.0  동일로 752  중화동 한신아파트(103~109)  서울특별시 중랑구 중화동    450
#
# [818137 rows x 13 columns]

# %%
len(apart_df['동_단지'].unique())
# Out:
# 8865

# %%
# 문제 데이터 갯수 확인
len(apt_df.loc[(apt_df['road']!=apt_df['new_road'])].index)
# Out:
# 4159

# %%
# 빈 리스트 정의
apt_lst2 = []

# %%
apt_df=apt_df[apt_df['road']!=" "]
apt_df
# Out:
#                       apt          road            new_apt      new_road  \
# 0      개포동 개포2차현대아파트(220)       언주로 103       개포현대2차(220동)           개포동
# 1      개포동 개포6차우성아파트1동~8동         언주로 3            정든우성6단지       불정로 195
# 2              개포동 개포우성3차       개포로 307               우성3차       개포로 307
# 3              개포동 개포우성3차       개포로 307               우성3차       개포로 307
# 4              개포동 개포우성3차       개포로 307               우성3차       개포로 307
# ...                   ...           ...                ...           ...
# 31043     장안동 에스아이팰리스장안센텀      한천로2길 84  에스아이팰리스장안센텀(주상복합)      한천로2길 84
# 31044     장안동 에스아이팰리스장안센텀      한천로2길 84  에스아이팰리스장안센텀(주상복합)      한천로2길 84
# 31045        장안동 청명에버아트2차  장한로21길 19-15     청명에버아트2차(주상복합)  장한로21길 19-15
# 31046        장안동 청명에버아트2차  장한로21길 19-15     청명에버아트2차(주상복합)  장한로21길 19-15
# 31047       휘경동 캠퍼스드림오피스텔        이문로 10              캠퍼스드림        이문로 10
#
#         latitude   longitude                 company  home_cnt  home_size  \
# 0      37.481215  127.052733               현대산업개발(주)        54      77.75
# 1      37.361885  127.122656  수도배관(공용배관) 교체완료(2014년)       706      84.97
# 2      37.483998  127.056011                 우성건설(주)       405     104.43
# 3      37.483998  127.056011                 우성건설(주)       405     133.46
# 4      37.483998  127.056011                 우성건설(주)       405     161.00
# ...          ...         ...                     ...       ...        ...
# 31043  37.562386  127.063230               (주)성우에스아이        99      28.75
# 31044  37.562386  127.063230               (주)성우에스아이        99      47.20
# 31045  37.569645  127.068760                주식회사지성건설        18      37.07
# 31046  37.569645  127.068760                주식회사지성건설        18      48.72
# 31047  37.588768  127.054688                에스원건설(주)        52      21.29
#
#       room_cnt bath_cnt  bigo zibun new_zibun
# 0            3        1  None  None      None
# 1            3        2  None  None      None
# 2            3        1  None  None      None
# 3            4        2  None  None      None
# 4            5        2  None  None      None
# ...        ...      ...   ...   ...       ...
# 31043        2        1  None  None      None
# 31044        3        1  None  None      None
# 31045        1        1  None  None      None
# 31046        2        1  None  None      None
# 31047        1        1  None  None      None
#
# [30883 rows x 14 columns]

# %%
apart_df[apart_df['단지명']=='연세7차B동']

# %%
a = apt_df.loc[(apt_df['road']!=apt_df['new_road'])].index[3242]
apt = apt_df.apt[a]
road = apt_df.road[a]
apt, road
# Out:
# ('창천동 하이펠리스', '연희로2안길 7-22')

# %%
# 데이터 수집
for a1 in range(2800, len(apt_df.loc[(apt_df['road']!=apt_df['new_road'])].index) ):
    try:
        try:
            a = apt_df.loc[(apt_df['road']!=apt_df['new_road'])].index[a1]
            apt = apt_df.apt[a]
            road = apt_df.road[a]
            sch = (apart_df[(apart_df.동_단지.str.startswith(apt_df.apt[a])) & (apart_df.도로명 == apt_df.road[a])]['시군구'] + ' ' + apart_df[(apart_df.동_단지.str.startswith(apt_df.apt[a])) & (apart_df.도로명 == apt_df.road[a])]['번지']).unique()[0]
            sch_road = apart_df[(apart_df.동_단지.str.startswith(apt_df.apt[a])) & (apart_df.도로명 == apt_df.road[a])]['시군구'].unique()[0].split(' ')[-2] + ' ' + road
            zibun = sch.split('특별시 ')[-1]
            apt_nm = 'None'
            road_nm = 'None'
            lat = '0'
            long = '0'
            home = '0'
            apt_company = 'None'
            size = '0'
            room = '0'
            bath = '0'
            bigo = 'None'
            zibun_nm = 'None'
            rt = 0
            max_i = 0
            web = Chrome('C:/pydata/chromedriver.exe')
            web.get('https://search.naver.com/search.naver?where=nexearch&sm=top_hty&fbm=0&ie=utf8&query=' + sch)
            web.implicitly_wait(5)

            try:
                web.find_element(By.CSS_SELECTOR, '#loc-main-section-root > section > div > div._3ttP1 > div > div._2p8Of > div._2ZgN5 > div._1oJkn > span:nth-child(2)')
                apt_nm = web.find_element(By.CSS_SELECTOR, '#loc-main-section-root > section > div > div._3ttP1 > div > div._2p8Of > div._2ZgN5 > div._1oJkn > span:nth-child(2)').text.split('도로명')[0]
            except:
                web.get('https://search.naver.com/search.naver?where=nexearch&sm=top_hty&fbm=0&ie=utf8&query=' + sch_road)
                web.implicitly_wait(5)
                try:
                    web.find_element(By.CSS_SELECTOR, '#loc-main-section-root > section > div > div._3ttP1 > div > div._2p8Of > div._2ZgN5 > div._1oJkn > span:nth-child(2)')
                    apt_nm = web.find_element(By.CSS_SELECTOR, '#loc-main-section-root > section > div > div._3ttP1 > div > div._2p8Of > div._2ZgN5 > div._1oJkn > span:nth-child(2)').text.split('지번')[0]
                except:
                    apt_nm=''


            if apt_nm != '':
                web.get('https://new.land.naver.com/complexes/667?ms=37.483998,127.056011,17&a=APT:ABYG:JGC&e=RETAIL')
                web.implicitly_wait(5)
                web.find_element(By.ID, 'search_input').clear()
                web.find_element(By.ID, 'search_input').send_keys(apt_nm)
                web.find_element(By.XPATH,'//*[@id="wrap"]/header/div[1]/form/fieldset/button[1]').click()
                web.implicitly_wait(5)

                try:
                    web.find_element(By.CSS_SELECTOR,'#ct > div.map_wrap > div.search_panel > div.list_fixed > div')
                    try:
                        web.find_element(By.XPATH, '//*[@id="ct"]/div[2]/div[2]/div[2]/div/div/div/div/i')
                        print('error', a1,  a, apt)
                        apt_lst2.append({'apt':apt,'zibun':zibun, 'new_zibun':zibun_nm, 'new_apt':apt_nm, 'road':road, 'new_road':road_nm, 'latitude':lat, 'longitude':long, 'company':apt_company, 'home_cnt':home, 'home_size':size, 'room_cnt':room, 'bath_cnt':bath, 'bigo':bigo})
                    except:
                        num_lst = []
                        for i in range(len(web.find_element(By.CSS_SELECTOR, '#ct > div.map_wrap > div.search_panel > div.list_contents > div').find_elements(By.CLASS_NAME, 'item'))):
                            if (len(web.find_element(By.CSS_SELECTOR,'#ct > div.map_wrap > div.search_panel > div.list_contents > div > div > div:nth-child('+str(i+1)+') > div > a').find_elements(By.CSS_SELECTOR,'*')) > 1):
                                if (web.find_element(By.CSS_SELECTOR, '#ct > div.map_wrap > div.search_panel > div.list_contents > div > div > div:nth-child('+str(i+1)+') > div > a > div.info_area > strong').text == '아파트') & (web.find_element(By.CSS_SELECTOR, '#ct > div.map_wrap > div.search_panel > div.list_contents > div > div > div:nth-child('+str(i+1)+') > div > a > div.address').text.endswith(apart_df[(apart_df.동_단지.str.startswith(apt_df.apt[a])) & (apart_df.도로명 == apt_df.road[a])]['시군구'].unique()[0].split('특별시 ')[-1])):
                                    num_lst.append(i)
                        if len(num_lst)==1:
                            max_i = num_lst[0]
                        elif len(num_lst) > 1:
                            for ii in num_lst:
                                web.find_element(By.CSS_SELECTOR, '#ct > div.map_wrap > div.search_panel > div.list_contents > div > div > div:nth-child('+str(ii+1)+')').click()
                                web.implicitly_wait(5)
                                web.find_element(By.XPATH,'//*[@id="summaryInfo"]/div[2]/div[2]/button[1]').click()
                                web.implicitly_wait(5)
                                if (web.find_elements(By.CSS_SELECTOR,'#detailContents1 > div.detail_box--complex > table > tbody > tr:nth-child(7) > td > p:nth-child(2)')[-1].text.split('구 ')[-1].split(' ')[0].endswith(road.split(' ')[0])) or (web.find_element(By.CSS_SELECTOR, '#detailContents1 > div.detail_box--complex > table > tbody > tr:nth-child(7) > td > p:nth-child(1)').text.split('-')[0].endswith(sch.split('특별시 ')[-1].split('-')[0])):
                                    zibun_nm1 = web.find_element(By.CSS_SELECTOR, '#detailContents1 > div.detail_box--complex > table > tbody > tr:nth-child(7) > td > p:nth-child(1)').text.split('시 ')[-1]
                                    road_nm1 = web.find_elements(By.CLASS_NAME,'address')[-1].text.split('구 ')[-1]
                                    if max(SequenceMatcher(None,zibun,zibun_nm1).ratio(), SequenceMatcher(None,road,road_nm1).ratio()) > rt:
                                        rt = max(SequenceMatcher(None,zibun,zibun_nm1).ratio(), SequenceMatcher(None,road,road_nm1).ratio())
                                        max_i = ii
                                web.find_element(By.ID, 'search_input').send_keys(apt_nm)
                                web.find_element(By.XPATH,'//*[@id="wrap"]/header/div[1]/form/fieldset/button[1]').click()
                                web.implicitly_wait(5)
                        web.find_element(By.CSS_SELECTOR, '#ct > div.map_wrap > div.search_panel > div.list_contents > div > div > div:nth-child('+str(max_i+1)+')').click()
                        web.implicitly_wait(5)
                        web.find_element(By.XPATH,'//*[@id="summaryInfo"]/div[2]/div[2]/button[1]').click()
                        web.implicitly_wait(5)
                        zibun_nm = web.find_element(By.CSS_SELECTOR, '#detailContents1 > div.detail_box--complex > table > tbody > tr:nth-child(7) > td > p:nth-child(1)').text.split('시 ')[-1]
                        road_nm = web.find_elements(By.CLASS_NAME,'address')[-1].text.split('구 ')[-1]
                        apt_nm = web.find_element(By.ID,'complexTitle').text
                        lat = web.current_url.split('=')[1].split(',')[0]
                        long = web.current_url.split('=')[1].split(',')[1]
                        home = web.find_element(By.CSS_SELECTOR,'#detailContents1 > div.detail_box--complex > table > tbody > tr:nth-child(1) > td:nth-child(2)').text.split('세대')[0]
                        apt_company = web.find_elements(By.CLASS_NAME, 'info_table_item')[3].find_element(By.CLASS_NAME, 'table_td').text
                        try:
                            web.find_element(By.XPATH,'//*[@id="detailContents1"]/div[2]/div[2]/div/div[2]/button')
                            web.find_element(By.XPATH,'//*[@id="detailContents1"]/div[2]/div[2]/div/div[2]/button').click()
                        except:
                            pass
                        for n in range(len(web.find_elements(By.CLASS_NAME,'detail_sorting_inner')[0].find_elements(By.CLASS_NAME,'detail_sorting_tab'))):
                            web.find_element(By.XPATH,'//*[@id="tab' + str(n) + '"]').click()
                            web.implicitly_wait(3)
                            size = web.find_element(By.XPATH,'/html/body/div[2]/div/section/div[2]/div[2]/div/div[2]/div[3]/div[2]/div[3]/table/tbody/tr[1]/td').text.split('㎡')[1][1:]
                            room = web.find_element(By.XPATH,'/html/body/div[2]/div/section/div[2]/div[2]/div/div[2]/div[3]/div[2]/div[3]/table/tbody/tr[2]/td').text.split('/')[0][:1]
                            bath = web.find_element(By.XPATH,'/html/body/div[2]/div/section/div[2]/div[2]/div/div[2]/div[3]/div[2]/div[3]/table/tbody/tr[2]/td').text.split('/')[1][:1]

                            apt_lst2.append({'apt':apt,'zibun':zibun, 'new_zibun':zibun_nm, 'new_apt':apt_nm, 'road':road, 'new_road':road_nm, 'latitude':lat, 'longitude':long, 'company':apt_company, 'home_cnt':home, 'home_size':size, 'room_cnt':room, 'bath_cnt':bath, 'bigo':bigo})

                except:
                    try:
                        web.find_element(By.CSS_SELECTOR, '#summaryInfo')
                        web.find_element(By.XPATH,'//*[@id="summaryInfo"]/div[2]/div[2]/button[1]').click()
                        web.implicitly_wait(5)
                        zibun_nm = web.find_element(By.CSS_SELECTOR, '#detailContents1 > div.detail_box--complex > table > tbody > tr:nth-child(7) > td > p:nth-child(1)').text.split('시 ')[-1]
                        road_nm = web.find_elements(By.CLASS_NAME,'address')[-1].text.split('구 ')[-1]
                        apt_nm = web.find_element(By.ID,'complexTitle').text
                        lat = web.current_url.split('=')[1].split(',')[0]
                        long = web.current_url.split('=')[1].split(',')[1]
                        home = web.find_element(By.CSS_SELECTOR,'#detailContents1 > div.detail_box--complex > table > tbody > tr:nth-child(1) > td:nth-child(2)').text.split('세대')[0]
                        apt_company = web.find_elements(By.CLASS_NAME, 'info_table_item')[3].find_element(By.CLASS_NAME, 'table_td').text
                        try:
                            web.find_element(By.XPATH,'//*[@id="detailContents1"]/div[2]/div[2]/div/div[2]/button')
                            web.find_element(By.XPATH,'//*[@id="detailContents1"]/div[2]/div[2]/div/div[2]/button').click()
                        except:
                            pass
                        for n in range(len(web.find_elements(By.CLASS_NAME,'detail_sorting_inner')[0].find_elements(By.CLASS_NAME,'detail_sorting_tab'))):
                            web.find_element(By.XPATH,'//*[@id="tab' + str(n) + '"]').click()
                            web.implicitly_wait(3)
                            size = web.find_element(By.CSS_SELECTOR,'#tabpanel > table > tbody > tr:nth-child(1) > td').text.split('㎡')[1][1:]
                            room = web.find_element(By.CSS_SELECTOR,'#tabpanel > table > tbody > tr:nth-child(2) > td').text.split('/')[0][:1]
                            bath = web.find_element(By.CSS_SELECTOR,'#tabpanel > table > tbody > tr:nth-child(2) > td').text.split('/')[1][:1]

                            apt_lst2.append({'apt':apt,'zibun':zibun, 'new_zibun':zibun_nm, 'new_apt':apt_nm, 'road':road, 'new_road':road_nm, 'latitude':lat, 'longitude':long, 'company':apt_company, 'home_cnt':home, 'home_size':size, 'room_cnt':room, 'bath_cnt':bath, 'bigo':bigo})

                    except:
                            web.get('https://search.naver.com/search.naver?where=nexearch&sm=top_hty&fbm=0&ie=utf8&query=' + sch_road)
                            web.implicitly_wait(5)
                            try:
                                web.find_element(By.CSS_SELECTOR, '#loc-main-section-root > section > div > div._3ttP1 > div > div._2p8Of > div._2ZgN5 > div._1oJkn > span:nth-child(2)')
                                apt_nm = web.find_element(By.CSS_SELECTOR, '#loc-main-section-root > section > div > div._3ttP1 > div > div._2p8Of > div._2ZgN5 > div._1oJkn > span:nth-child(2)').text.split('지번')[0]
                            except:
                                apt_nm = ''
                                bigo='아파트없음'
                                print('error', a1, a, apt)
                                apt_lst2.append({'apt':apt,'zibun':zibun, 'new_zibun':zibun_nm, 'new_apt':apt_nm, 'road':road, 'new_road':road_nm, 'latitude':lat, 'longitude':long, 'company':apt_company, 'home_cnt':home, 'home_size':size, 'room_cnt':room, 'bath_cnt':bath, 'bigo':bigo})

                            if apt_nm != '':
                                web.get('https://new.land.naver.com/complexes/667?ms=37.483998,127.056011,17&a=APT:ABYG:JGC&e=RETAIL')
                                web.implicitly_wait(5)
                                web.find_element(By.ID, 'search_input').clear()
                                web.find_element(By.ID, 'search_input').send_keys(apt_nm)
                                web.find_element(By.XPATH,'//*[@id="wrap"]/header/div[1]/form/fieldset/button[1]').click()
                                web.implicitly_wait(5)
                                try:
                                    web.find_element(By.CSS_SELECTOR,'#ct > div.map_wrap > div.search_panel > div.list_fixed > div')
                                    try:
                                        web.find_element(By.XPATH, '//*[@id="ct"]/div[2]/div[2]/div[2]/div/div/div/div/i')
                                        print('error', a1,  a, apt)
                                        apt_lst2.append({'apt':apt,'zibun':zibun, 'new_zibun':zibun_nm, 'new_apt':apt_nm, 'road':road, 'new_road':road_nm, 'latitude':lat, 'longitude':long, 'company':apt_company, 'home_cnt':home, 'home_size':size, 'room_cnt':room, 'bath_cnt':bath, 'bigo':bigo})
                                    except:
                                        num_lst = []
                                        for i in range(len(web.find_element(By.CSS_SELECTOR, '#ct > div.map_wrap > div.search_panel > div.list_contents > div').find_elements(By.CLASS_NAME, 'item'))):
                                            if (len(web.find_element(By.CSS_SELECTOR,'#ct > div.map_wrap > div.search_panel > div.list_contents > div > div > div:nth-child('+str(i+1)+') > div > a').find_elements(By.CSS_SELECTOR,'*')) > 1):
                                                if (web.find_element(By.CSS_SELECTOR, '#ct > div.map_wrap > div.search_panel > div.list_contents > div > div > div:nth-child('+str(i+1)+') > div > a > div.info_area > strong').text == '아파트') & (web.find_element(By.CSS_SELECTOR, '#ct > div.map_wrap > div.search_panel > div.list_contents > div > div > div:nth-child('+str(i+1)+') > div > a > div.address').text.endswith(apart_df[(apart_df.동_단지.str.startswith(apt_df.apt[a])) & (apart_df.도로명 == apt_df.road[a])]['시군구'].unique()[0].split('특별시 ')[-1])):
                                                    num_lst.append(i)
                                        if len(num_lst)==1:
                                            max_i = num_lst[0]
                                        elif len(num_lst)>1:
                                            for i in num_lst:
                                                web.find_element(By.CSS_SELECTOR, '#ct > div.map_wrap > div.search_panel > div.list_contents > div > div > div:nth-child('+str(i+1)+')').click()
                                                web.implicitly_wait(5)
                                                web.find_element(By.XPATH,'//*[@id="summaryInfo"]/div[2]/div[2]/button[1]').click()
                                                web.implicitly_wait(5)
                                                if (web.find_elements(By.CSS_SELECTOR,'#detailContents1 > div.detail_box--complex > table > tbody > tr:nth-child(7) > td > p:nth-child(2)')[-1].text.split('구 ')[-1].split(' ')[0].endswith(road.split(' ')[0])) and (web.find_element(By.CSS_SELECTOR, '#detailContents1 > div.detail_box--complex > table > tbody > tr:nth-child(7) > td > p:nth-child(1)').text.split('-')[0].endswith(sch.split('특별시 ')[-1].split('-')[0])):
                                                    zibun_nm1 = web.find_element(By.CSS_SELECTOR, '#detailContents1 > div.detail_box--complex > table > tbody > tr:nth-child(7) > td > p:nth-child(1)').text.split('시 ')[-1]
                                                    road_nm1 = web.find_elements(By.CLASS_NAME,'address')[-1].text.split('구 ')[-1]
                                                    if max(SequenceMatcher(None,zibun,zibun_nm1).ratio(), SequenceMatcher(None,road,road_nm1).ratio()) > rt:
                                                        rt = max(SequenceMatcher(None,zibun,zibun_nm1).ratio(), SequenceMatcher(None,road,road_nm1).ratio())
                                                        max_i = i
                                                web.find_element(By.ID, 'search_input').send_keys(apt_nm)
                                                web.find_element(By.XPATH,'//*[@id="wrap"]/header/div[1]/form/fieldset/button[1]').click()
                                                web.implicitly_wait(5)
                                        web.find_element(By.CSS_SELECTOR, '#ct > div.map_wrap > div.search_panel > div.list_contents > div > div > div:nth-child('+str(max_i+1)+')').click()
                                        web.implicitly_wait(5)
                                        web.find_element(By.XPATH,'//*[@id="summaryInfo"]/div[2]/div[2]/button[1]').click()
                                        web.implicitly_wait(5)
                                        zibun_nm = web.find_element(By.CSS_SELECTOR, '#detailContents1 > div.detail_box--complex > table > tbody > tr:nth-child(7) > td > p:nth-child(1)').text.split('시 ')[-1]
                                        road_nm = web.find_elements(By.CLASS_NAME,'address')[-1].text.split('구 ')[-1]
                                        apt_nm = web.find_element(By.ID,'complexTitle').text
                                        lat = web.current_url.split('=')[1].split(',')[0]
                                        long = web.current_url.split('=')[1].split(',')[1]
                                        home = web.find_element(By.CSS_SELECTOR,'#detailContents1 > div.detail_box--complex > table > tbody > tr:nth-child(1) > td:nth-child(2)').text.split('세대')[0]
                                        try:
                                            web.find_element(By.XPATH,'//*[@id="detailContents1"]/div[2]/div[2]/div/div[2]/button')
                                            web.find_element(By.XPATH,'//*[@id="detailContents1"]/div[2]/div[2]/div/div[2]/button').click()
                                        except:
                                            pass
                                        for n in range(len(web.find_elements(By.CLASS_NAME,'detail_sorting_inner')[0].find_elements(By.CLASS_NAME,'detail_sorting_tab'))):
                                            web.find_element(By.XPATH,'//*[@id="tab' + str(n) + '"]').click()
                                            web.implicitly_wait(3)
                                            size = web.find_element(By.XPATH,'/html/body/div[2]/div/section/div[2]/div[2]/div/div[2]/div[3]/div[2]/div[3]/table/tbody/tr[1]/td').text.split('㎡')[1][1:]
                                            room = web.find_element(By.XPATH,'/html/body/div[2]/div/section/div[2]/div[2]/div/div[2]/div[3]/div[2]/div[3]/table/tbody/tr[2]/td').text.split('/')[0][:1]
                                            bath = web.find_element(By.XPATH,'/html/body/div[2]/div/section/div[2]/div[2]/div/div[2]/div[3]/div[2]/div[3]/table/tbody/tr[2]/td').text.split('/')[1][:1]

                                            apt_lst2.append({'apt':apt,'zibun':zibun, 'new_zibun':zibun_nm, 'new_apt':apt_nm, 'road':road, 'new_road':road_nm, 'latitude':lat, 'longitude':long, 'company':apt_company, 'home_cnt':home, 'home_size':size, 'room_cnt':room, 'bath_cnt':bath, 'bigo':bigo})
                                except:
                                    print('error', a1, a, apt)
                                    bigo = '아파트없음'
                                    apt_lst2.append({'apt':apt,'zibun':zibun, 'new_zibun':zibun_nm, 'new_apt':apt_nm, 'road':road, 'new_road':road_nm, 'latitude':lat, 'longitude':long, 'company':apt_company, 'home_cnt':home, 'home_size':size, 'room_cnt':room, 'bath_cnt':bath, 'bigo':bigo})
            else:
                print('error', a1, a, apt)
                bigo = '아파트없음'
                apt_lst2.append({'apt':apt,'zibun':zibun, 'new_zibun':zibun_nm, 'new_apt':apt_nm, 'road':road, 'new_road':road_nm, 'latitude':lat, 'longitude':long, 'company':apt_company, 'home_cnt':home, 'home_size':size, 'room_cnt':room, 'bath_cnt':bath, 'bigo':bigo})

        except:
                print('error', a1, a, apt)
                bigo = '아파트없음'
    except:
        print('name_error', a1, a, apt)
# Out:
# C:\Users\jhgf\AppData\Local\Temp\ipykernel_11924\185743063.py:24: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   web = Chrome('C:/pydata/chromedriver.exe')
# error 2800 23203 진관동 은평뉴타운상림마을(현대아이파크B-4)
# error 2801 23204 진관동 은평뉴타운상림마을(현대아이파크B-4)
# error 2802 23205 진관동 은평뉴타운상림마을(현대아이파크B-4)
# error 2803 23206 진관동 은평뉴타운우물골(두산위브4단지)
# error 2804 23207 진관동 은평뉴타운우물골(두산위브5단지)
# error 2805 23208 진관동 은평뉴타운우물골(두산위브6단지)
# error 2806 23209 진관동 은평뉴타운우물골(두산위브7단지)
# error 2807 23210 진관동 은평뉴타운우물골(두산위브8단지)
# error 2808 23215 진관동 은평뉴타운폭포동(힐스테이트D-11)
# error 2809 23216 진관동 은평뉴타운폭포동(힐스테이트D-9)
# error 2810 23248 내수동 경희궁파크팰리스
# error 2811 23259 당주동 롯데미도파광화문빌딩
# error 2813 23300 부암동 별빛고운
# error 2816 23322 숭인동 숭인동103동(569-4)
# error 2817 23323 숭인동 숭인동104동(569-2)
# error 2818 23324 숭인동 숭인동105동(569-3)
# error 2819 23333 숭인동 숭인한양LEEPS
# error 2824 23362 연건동 (60-1)
# error 2840 23438 창신동 성용
# error 2847 23569 신당동 (432-904)
# error 2848 23570 신당동 GV
# error 2849 23571 신당동 각산빌
# error 2866 23588 신당동 글로리안(B)
# error 2867 23635 신당동 도현블랑빌
# error 2868 23636 신당동 동산빌라(2차)
# error 2869 23637 신당동 동평화패션타운
# error 2872 23678 신당동 신신(1차)
# error 2873 23679 신당동 약수(372-13)
# error 2874 23688 신당동 인성아트빌
# error 2875 23715 신당동 탑힐
# error 2877 23741 신당동 푸른마을(B)
# error 2879 23857 황학동 한양I-Class
# error 2880 23866 흥인동 aaa
# error 2892 24083 면목동 두산3
# error 2893 24084 면목동 두산3
# error 2908 24349 묵동 우성
# error 2909 24350 묵동 우성
# error 2910 24351 묵동 우성
# error 2911 24352 묵동 우성
# error 2912 24353 묵동 우성
# error 2913 24354 묵동 우성
# error 2914 24355 묵동 우성
# error 2915 24356 묵동 우성
# error 2916 24357 묵동 우성
# error 2917 24358 묵동 우성
# error 2926 24449 상봉동 주함해븐타워
# error 2927 24450 상봉동 주함해븐타워
# error 2928 24451 상봉동 주함해븐타워
# error 2929 24452 상봉동 주함해븐타워
# error 2930 24453 상봉동 주함해븐타워
# error 2931 24454 상봉동 주함해븐타워
# error 2932 24455 상봉동 주함해븐타워
# error 2959 24700 신내동 화성.두산아파트
# error 2963 24723 중화동 미영리치타운103
# error 2964 24725 중화동 삼익아파트.상가동
# error 2971 24806 개포동 아람손프라자/비바빌
# error 2985 24921 세곡동 강남엘에이치1단지
# error 3010 25063 수유동 정원
# error 3023 25183 화곡동 그레이스(786-10)
# error 3055 25263 화곡동 우공팰리스102동
# error 3060 25295 화곡동 토석아네스아파트
# error 3065 25334 남현동 플라워스위트101동102동
# error 3068 25411 봉천동 서희스타힐스
# error 3069 25412 봉천동 서희스타힐스
# error 3070 25413 봉천동 서희스타힐스
# error 3071 25414 봉천동 서희스타힐스
# error 3072 25415 봉천동 서희스타힐스
# error 3073 25416 봉천동 서희스타힐스
# error 3074 25417 봉천동 서희스타힐스
# error 3080 25525 군자동 서원힐탑
# error 3081 25526 군자동 서원힐탑
# error 3082 25527 군자동 서원힐탑
# error 3083 25528 군자동 서원힐탑
# error 3084 25529 군자동 서원힐탑
# error 3085 25530 군자동 서원힐탑
# error 3086 25531 군자동 서원힐탑
# error 3092 25573 구로동 (717-15)경원주택5동
# error 3093 25574 구로동 (717-20)한성
# error 3094 25575 구로동 (717-23)함양주택
# error 3095 25576 구로동 (718-29)청원아트빌라
# error 3096 25577 구로동 (740-21)
# error 3097 25578 구로동 (740-25)
# error 3098 25579 구로동 (741-7)
# error 3099 25580 구로동 (742-58)
# error 3100 25581 구로동 (742-64)
# error 3101 25582 구로동 (743-10)
# error 3102 25583 구로동 (743-33)
# error 3103 25584 구로동 (743-60)
# error 3104 25585 구로동 (744-23)
# error 3105 25586 구로동 (744-3)
# error 3106 25587 구로동 (744-45)
# error 3107 25588 구로동 (745-10)
# error 3108 25589 구로동 (745-40)
# error 3109 25590 구로동 (745-43)
# error 3110 25591 구로동 (745-57)
# error 3111 25592 구로동 (747-34)
# error 3112 25593 구로동 (748-48)
# error 3113 25594 구로동 (749-1)
# error 3114 25595 구로동 (749-30)
# error 3115 25596 구로동 (749-99)
# error 3116 25597 구로동 (750-8)
# error 3117 25598 구로동 (752-37)
# error 3118 25599 구로동 (770-52)
# error 3119 25600 구로동 (771-2)
# error 3120 25601 구로동 (771-30)
# error 3121 25602 구로동 (779-2)
# error 3122 25603 구로동 (779-3)
# error 3123 25604 구로동 (780-31)
# error 3124 25605 구로동 (780-41)
# error 3125 25606 구로동 (780-72)삼익빌라
# error 3126 25607 구로동 (792-11)
# error 3127 25608 구로동 (792-86)
# error 3128 25609 구로동 (793-24)
# error 3129 25610 구로동 (793-54)
# error 3130 25611 구로동 (793-6)
# error 3131 25612 구로동 (794-13)
# error 3132 25613 구로동 (794-24)
# error 3133 25614 구로동 (796-51)
# error 3134 25615 구로동 (797-26)
# error 3135 25616 구로동 (797-5)
# error 3136 25617 구로동 (798-26)
# error 3137 25618 구로동 (801-32)
# error 3138 25619 구로동 (803-13)구로아트빌라8
# error 3139 25620 구로동 (803-29)
# error 3140 25621 구로동 (805-16)
# error 3141 25622 구로동 (806-15)
# error 3142 25623 구로동 (807-29)
# error 3143 25624 구로동 801-9
# error 3144 25625 구로동 807-41
# error 3146 25627 구로동 궁전아트빌라
# error 3148 25647 구로동 삼주빌라
# error 3149 25648 구로동 서원빌라
# error 3150 25649 구로동 유진빌라
# error 3151 25650 구로동 은진빌라
# error 3152 25651 구로동 청송빌라
# error 3153 25652 구로동 태양
# error 3154 25656 구로동 하나세인스톤Ⅴ
# error 3155 25657 구로동 한신
# error 3156 25658 구로동 현암B동
# error 3157 25659 구로동 황산(791-12)
# error 3159 25673 오류동 미진주택B동
# error 3167 25702 독산동 은탑로얄클라스
# error 3170 25711 시흥동 우성
# error 3171 25712 시흥동 우성
# error 3172 25717 공릉동 공릉1단지아파트
# error 3187 25762 월계동 꿈의숲SKVIEW
# error 3188 25763 도봉동 삼안리치
# error 3202 25843 장안동 가우디트윈캐슬1
# error 3204 25854 장안동 비젼아파트102동
# error 3214 25864 장안동 장안트윈A동
# error 3217 25867 장안동 태솔아파트1차
# error 3218 25868 장안동 태솔아파트2차
# error 3219 25869 전농동 퍼시픽하우스44차
# error 3223 25924 사당동 동문아트빌
# error 3226 25938 상도1동 평화그린
# error 3233 26053 성산동 성산동자담이움아파트
# error 3238 26196 북아현동 진흥1차
# error 3240 26225 연희동 홍연
# error 3241 26226 연희동 홍연
# error 3278 26285 홍제동 동일5차101동
# error 3280 26372 반포동 윌턴빌
# error 3287 26402 방배동 롯데빌라트2차
# error 3288 26406 방배동 모닝아트빌
# error 3296 26465 방배동 월드빌리지
# error 3297 26466 방배동 월드빌리지
# error 3298 26467 방배동 월드빌리지
# error 3299 26468 방배동 월드빌리지
# error 3301 26478 서초동 N-Suite(1513-2)
# error 3302 26490 서초동 동아빌리지
# error 3304 26543 서초동 서초아트빌
# error 3305 26544 서초동 서초아파트
# error 3306 26545 서초동 서초아파트
# error 3323 26653 길음동 두이노블레스(2)
# error 3329 26702 가락동 쌍용스윗닷홈(104동)
# error 3330 26703 가락동 쌍용스윗닷홈(104동)
# error 3331 26704 가락동 쌍용스윗닷홈(104동)
# error 3332 26705 가락동 쌍용스윗닷홈(104동)
# error 3333 26706 가락동 쌍용스윗닷홈(104동)
# error 3334 26707 가락동 쌍용스윗닷홈(104동)
# error 3335 26708 가락동 쌍용스윗닷홈(104동)
# error 3337 26721 문정동 동궁리치웰문정(2차)
# error 3345 26859 오금동 오륜파크빌
# error 3354 26987 신월동 동양브로미(102동)A
# error 3356 27009 신월동 장수마을2단지동원데쟈뷰
# error 3370 27076 대림동 다청림2동
# error 3371 27082 신길동 광산로얄
# error 3372 27106 동빙고동 리버힐에이동
# error 3386 27164 한남동 트윈빌비동
# error 3387 27165 한남동 트윈빌에이동
# error 3388 27166 한남동 한남동UNVILLAGE루하우스
# error 3389 27191 후암동 삼안리치8차
# error 3390 27206 후암동 힐튼빌리지2차
# error 3396 27292 대조동 주주베B
# error 3397 27293 대조동 초원넥스빌
# error 3398 27328 수색동 제일아파트가동(345-4)
# error 3401 27343 신사동 양지파크
# error 3419 27400 응암동 형미그린(101)
# error 3420 27401 응암동 형미그린(758-0)
# error 3426 27496 창신동 일우
# error 3427 27523 신당동 명경아트빌
# error 3429 27539 신당동 청구103동
# error 3431 27541 황학동 (1546-0)
# error 3434 27566 면목동 진성그린건설테라스아파트
# error 3438 27634 개포동 시영
# error 3439 27635 개포동 시영
# error 3440 27636 개포동 시영
# error 3441 27637 개포동 시영
# error 3442 27638 개포동 시영
# error 3443 27639 개포동 시영
# error 3444 27640 개포동 시영
# error 3445 27641 개포동 시영
# error 3446 27642 개포동 시영
# error 3447 27643 개포동 시영
# error 3448 27644 개포동 시영
# error 3449 27645 개포동 시영
# error 3450 27646 개포동 시영
# error 3451 27647 개포동 시영
# error 3452 27648 개포동 시영
# error 3459 27753 세곡동 강남엘에이치1단지
# error 3462 27787 자곡동 강남한양수자인(4단지)
# error 3463 27788 자곡동 강남한양수자인(4단지)
# error 3464 27789 자곡동 강남한양수자인(4단지)
# error 3465 27790 자곡동 강남한양수자인(4단지)
# error 3466 27791 자곡동 강남한양수자인(4단지)
# error 3467 27792 자곡동 강남한양수자인(4단지)
# error 3468 27793 자곡동 강남한양수자인(4단지)
# error 3469 27794 자곡동 강남한양수자인(4단지)
# error 3470 27795 자곡동 강남한양수자인(4단지)
# error 3471 27796 자곡동 강남한양수자인(4단지)
# error 3472 27797 자곡동 강남한양수자인(4단지)
# error 3473 27798 자곡동 강남한양수자인(4단지)
# error 3474 27799 자곡동 강남한양수자인(4단지)
# error 3482 27857 미아동 래미안트리베라2단지(임대)
# error 3496 27961 봉천동 관악동부센트레빌
# error 3497 27962 봉천동 관악동부센트레빌
# error 3498 27963 봉천동 관악동부센트레빌
# error 3499 27964 봉천동 관악동부센트레빌
# error 3509 28062 구로동 (716-17)
# error 3511 28064 구로동 (739-43)
# error 3512 28065 구로동 (742-57)
# error 3513 28066 구로동 (743-32)
# error 3514 28067 구로동 (743-39)
# error 3515 28068 구로동 (744-13)
# error 3516 28069 구로동 (744-15)
# error 3517 28070 구로동 (744-47)
# error 3518 28071 구로동 (744-48)
# error 3519 28072 구로동 (748-20)
# error 3520 28073 구로동 (749-46)
# error 3521 28074 구로동 (749-48)
# error 3522 28075 구로동 (750-6)
# error 3523 28076 구로동 (750-7)
# error 3524 28077 구로동 (752-19)
# error 3525 28078 구로동 (780-58)
# error 3526 28079 구로동 (780-62)
# error 3527 28080 구로동 (780-67)우정빌라
# error 3528 28081 구로동 (791-4)
# error 3529 28082 구로동 (791-62)
# error 3530 28083 구로동 (792-102)
# error 3531 28084 구로동 (792-98)
# error 3532 28085 구로동 (794-26)
# error 3533 28086 구로동 (796-3)
# error 3534 28087 구로동 (797-19)
# error 3535 28088 구로동 (797-38)
# error 3536 28089 구로동 (798-27)
# error 3537 28090 구로동 (806-40)
# error 3538 28091 구로동 (806-46)돌담
# error 3539 28092 구로동 (807-23)
# error 3540 28093 구로동 800-19
# error 3541 28094 구로동 남구로
# error 3543 28096 구로동 모란빌라
# error 3544 28097 구로동 영광빌라
# error 3545 28098 구로동 장미빌라
# error 3546 28099 구로동 장수(796-60)
# error 3547 28100 구로동 정창빌라
# error 3548 28101 구로동 제일
# error 3549 28102 구로동 제일(805-14)
# error 3550 28103 구로동 조성빌라
# error 3551 28104 구로동 한신주택
# error 3555 28158 방학동 우성아파트1
# error 3556 28159 방학동 우성아파트1
# error 3557 28160 방학동 우성아파트1
# error 3558 28161 방학동 우성아파트1
# error 3559 28162 방학동 우성아파트1
# error 3562 28196 장안동 가우디트윈캐슬2
# error 3563 28197 장안동 대성하이빌(B동)
# error 3566 28202 장안동 젬스톤힐즈
# error 3567 28224 노량진동 벧엘ForZoom
# error 3571 28243 상도동 백촌빌라트
# error 3576 28319 남가좌동 디엠씨엘가
# error 3593 28336 연희동 로엠아트빌(A동)
# error 3594 28337 연희동 성원쌍떼빌팰리스
# error 3595 28338 연희동 연희궁그린빌라트
# error 3608 28375 반포동 몽마르뜨파크
# error 3611 28416 방배동 TheHerren
# error 3613 28456 방배동 서리풀e편한세상
# error 3614 28457 방배동 서리풀e편한세상
# error 3615 28458 방배동 서리풀e편한세상
# error 3616 28459 방배동 서리풀e편한세상
# error 3617 28460 방배동 서리풀e편한세상
# error 3618 28461 방배동 서리풀e편한세상
# error 3619 28462 방배동 서리풀e편한세상
# error 3620 28463 방배동 서리풀e편한세상
# error 3621 28484 서초동 N-Suite101동(1511-6)
# error 3622 28485 서초동 N-Suite102동(1511-3)
# error 3623 28489 서초동 다솔멤버스
# error 3658 28614 길음동 금호
# error 3661 28663 마천동 마천금호어울림1차아파트
# error 3662 28664 마천동 마천금호어울림1차아파트
# error 3663 28665 마천동 마천금호어울림1차아파트
# error 3664 28666 마천동 마천금호어울림1차아파트
# error 3665 28667 마천동 마천금호어울림1차아파트
# error 3666 28668 마천동 마천금호어울림1차아파트
# error 3670 28693 석촌동 비엔나빌
# error 3671 28696 송파동 대우레이크월드
# error 3672 28697 송파동 대우레이크월드
# error 3673 28698 송파동 대우레이크월드
# error 3674 28699 송파동 대우레이크월드
# error 3675 28700 송파동 대우레이크월드
# error 3676 28701 송파동 대우레이크월드
# error 3679 28757 목동 목동동화옥시죤-7
# error 3680 28758 목동 목동휘버스II
# error 3683 28834 주성동 PRIMAVERAVILL
# error 3685 28847 후암동 프리마베라빌
# error 3697 28883 대조동 정익제이원6차
# error 3698 28891 수색동 상아
# error 3709 28929 응암동 형미그린(758-0)
# error 3711 28938 진관동 은평뉴타운박석고개(힐스테이트12단지)
# error 3712 28939 진관동 은평뉴타운박석고개(힐스테이트12단지)
# error 3713 28940 진관동 은평뉴타운박석고개(힐스테이트12단지)
# error 3714 28941 진관동 은평뉴타운박석고개(힐스테이트12단지)
# error 3715 28953 교남동 경희궁자이(2단지)
# error 3716 28954 교남동 경희궁자이(2단지)
# error 3717 28955 교남동 경희궁자이(4단지)
# error 3719 28966 창신동 (627-120)
# error 3720 28967 청운동 청운현대
# error 3721 28968 청운동 청운현대
# error 3722 28969 청운동 청운현대
# error 3723 28970 청운동 청운현대
# error 3724 28971 청운동 청운현대
# error 3727 29004 신당동 남산FORESTHOUSE
# error 3728 29005 황학동 (1544-0)
# error 3729 29011 황학동 그랜드힐오피스텔
# error 3730 29012 황학동 그랜드힐오피스텔
# error 3731 29013 황학동 그랜드힐오피스텔
# error 3732 29014 황학동 그랜드힐오피스텔
# error 3733 29015 황학동 그랜드힐오피스텔
# error 3734 29016 황학동 그랜드힐오피스텔
# error 3743 29037 면목동 용마금호타운
# error 3744 29045 면목동 효성
# error 3745 29048 묵동 이편한세상화랑대
# error 3748 29089 도곡동 도곡현대힐스테이트101동
# error 3750 29199 화곡동 GMValley
# error 3752 29224 화곡동 신보
# error 3757 29249 화곡동 혜성오피아파트
# error 3758 29254 남현동 e산이랑
# error 3759 29255 남현동 한백다솜
# error 3762 29286 구로동 (716-22)우진빌라C
# error 3763 29287 구로동 (717-22)함양주택
# error 3764 29288 구로동 (744-19)
# error 3765 29289 구로동 (749-57)
# error 3766 29290 구로동 (752-15)
# error 3767 29291 구로동 (771-2)
# error 3768 29292 구로동 (791-13)우리빌라
# error 3769 29293 구로동 (792-10)
# error 3770 29294 구로동 (792-17)
# error 3771 29295 구로동 (796-65)삼성주택
# error 3772 29296 구로동 송림주택
# error 3773 29297 구로동 은진빌라(748-24)
# error 3774 29298 구로동 일심빌리지
# error 3775 29299 구로동 청원주택
# error 3776 29328 독산동 목화103
# error 3777 29337 시흥동 백운한비치5
# error 3779 29365 쌍문동 신성
# error 3780 29366 쌍문동 신성
# error 3781 29367 쌍문동 신성
# error 3783 29373 답십리동 답십리대우(임대)
# error 3784 29403 장안동 상록파라브2차
# error 3785 29404 장안동 엘림하우스2차
# error 3786 29405 장안동 태솔아파트3차
# error 3787 29406 전농동 봄봄하이츠
# error 3793 29440 서교동 엠제이더퍼스트홍대
# error 3800 29547 방배동 빌라일두오모
# error 3802 29626 잠원동 신사레전드
# error 3803 29637 돈암동 구현대
# error 3804 29639 가락동 시안헤븐스테이
# error 3806 29663 석촌동 나래파크빌
# error 3809 29821 교남동 경희궁자이(3단지)
# error 3810 29822 누상동 청호그린빌
# error 3815 29881 황학동 청계리버팰리스B
# error 3819 29955 도곡동 이니그마빌-III
# error 3820 29973 청담동 효성빌라청담101(B동)
# error 3827 30031 화곡동 프라임주택
# error 3828 30032 화곡동 한백E타운아파트
# error 3829 30033 화곡동 한백E타운아파트
# error 3830 30034 화곡동 한백E타운아파트
# error 3831 30035 화곡동 한백E타운아파트
# error 3833 30044 봉천동 e편한세상서울대입구1단지
# error 3835 30091 화양동 아스하임(111-102)
# error 3836 30099 구로동 (718-17)문화아트빌라
# error 3837 30100 구로동 (740-23)
# error 3838 30101 구로동 (743-19)
# error 3839 30102 구로동 (743-6)
# error 3840 30103 구로동 (749-4)
# error 3841 30104 구로동 (751-4)
# error 3842 30105 구로동 (770-50)
# error 3843 30106 구로동 (771-28)
# error 3844 30107 구로동 (792-6)
# error 3845 30108 구로동 (793-13)
# error 3846 30109 구로동 (797-22)
# error 3847 30110 구로동 (807-21)
# error 3848 30111 구로동 대길B
# error 3850 30113 구로동 성산E동
# error 3851 30138 항동 하버라인3단지
# error 3852 30139 항동 하버라인3단지
# error 3853 30140 항동 하버라인3단지
# error 3854 30141 항동 하버라인3단지
# error 3855 30142 항동 하버라인3단지
# error 3856 30143 항동 하버라인3단지
# error 3857 30144 항동 하버라인3단지
# error 3872 30212 방학동 성진파크뷰아파트
# error 3873 30287 장안동 푸른마을(284-3)
# error 3876 30371 염리동 마포자이3차
# error 3877 30407 연희동 홍연
# error 3878 30408 연희동 홍연
# error 3896 30566 방이동 주함위너스Ⅰ
# error 3898 30600 신월동 목동센트럴아이파크위브1단지
# error 3902 30650 대조동 모아아파트(103동)
# error 3917 30684 역촌동 태경맨션
# error 3920 30715 창신동 미니
# error 3921 30742 신당동 글로리안(A)
# error 3922 30743 신당동 남산리젠트힐
# error 3924 30848 청담동 효성빌라청담101(A동)
# error 3927 30880 봉천동 e편한세상서울대입구2단지
# error 3928 30881 봉천동 하이캐슬102동
# error 3929 30884 광장동 광장동현대Ⅰ빌라트
# error 3952 30932 화양동 신원리브웰화양동주상복합
# error 3953 30933 구로동 (718-10)옥천빌라
# error 3954 30934 구로동 (718-11)경원주택6동
# error 3955 30935 구로동 (718-12)부국주택
# error 3956 30936 구로동 (718-24)경원주택
# error 3957 30937 구로동 (743-5)
# error 3958 30938 구로동 (745-15)
# error 3959 30939 구로동 (745-60)
# error 3960 30940 구로동 (746-14)
# error 3961 30941 구로동 (749-39)
# error 3962 30942 구로동 (749-8)
# error 3963 30943 구로동 (770-29)
# error 3964 30944 구로동 (770-4)
# error 3965 30945 구로동 (770-54)
# error 3966 30946 구로동 (770-59)
# error 3969 30949 구로동 (792-2)
# error 3970 30950 구로동 (793-16)
# error 3971 30951 구로동 (793-46)
# error 3972 30952 구로동 (794-12)
# error 3973 30953 구로동 (796-13)
# error 3974 30954 구로동 (796-16)
# error 3975 30955 구로동 (796-25)
# error 3976 30956 구로동 (796-26)
# error 3977 30957 구로동 (797-43)
# error 3978 30958 구로동 (798-21)
# error 3979 30959 구로동 (807-37)
# error 3980 30960 구로동 801-14
# error 3981 30961 구로동 낙원빌라
# error 3982 30962 구로동 대영빌라
# error 3983 30963 구로동 명성빌라3차
# error 3984 30964 구로동 미도빌라A동
# error 3985 30965 구로동 보성
# error 3986 30969 구로동 안정빌라
# error 3989 30983 상계동 D.S아파트
# error 3991 31008 창동 창동역블루핀1동
# error 3992 31009 창동 창동역블루핀2동
# error 3993 31027 이문동 세진빌딩

# %%
# 데이터프레임 확인
pd.DataFrame(apt_lst2).to_csv("2800-4159.csv", index=False)
